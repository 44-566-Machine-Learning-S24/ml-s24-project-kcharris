# %% [markdown]
# ## 1.

# %%
import pandas as pd
data_frame = pd.read_csv("../ProjectResources/movies/movies_metadata.csv", low_memory=False)

# %%
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
# ...

# %%
data_frame.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
data_frame.describe()
# Out:
#             revenue       runtime  vote_average    vote_count
# count  4.546000e+04  45203.000000  45460.000000  45460.000000
# mean   1.120935e+07     94.128199      5.618207    109.897338
# std    6.433225e+07     38.407810      1.924216    491.310374
# min    0.000000e+00      0.000000      0.000000      0.000000
# 25%    0.000000e+00     85.000000      5.000000      3.000000
# 50%    0.000000e+00     95.000000      6.000000     10.000000
# 75%    0.000000e+00    107.000000      6.800000     34.000000
# max    2.787965e+09   1256.000000     10.000000  14075.000000

# %%
data_frame['genre'].value_counts()
# Out:
# budget
# 0           36573
# 5000000       286
# 10000000      259
# 20000000      243
# 2000000       242
#             ...
# 923             1
# 72500000        1
# 2160000         1
# 4439832         1
# 1254040         1
# Name: count, Length: 1226, dtype: int64

# %% [markdown]
# Budget is shown as an int64 type but is not listed in the describe, so I will manually change the data, as well as create a work copy of the data to modify.

# %%
work_copy = data_frame.copy()
work_copy['budget'] = pd.to_numeric(work_copy['budget'], errors='coerce')
work_copy.describe()
# Out:
#              budget       revenue       runtime  vote_average    vote_count
# count  4.546300e+04  4.546000e+04  45203.000000  45460.000000  45460.000000
# mean   4.224579e+06  1.120935e+07     94.128199      5.618207    109.897338
# std    1.742413e+07  6.433225e+07     38.407810      1.924216    491.310374
# min    0.000000e+00  0.000000e+00      0.000000      0.000000      0.000000
# 25%    0.000000e+00  0.000000e+00     85.000000      5.000000      3.000000
# 50%    0.000000e+00  0.000000e+00     95.000000      6.000000     10.000000
# 75%    0.000000e+00  0.000000e+00    107.000000      6.800000     34.000000
# max    3.800000e+08  2.787965e+09   1256.000000     10.000000  14075.000000

# %%
import matplotlib.pyplot as plt

work_copy.hist(bins=50)
plt.tight_layout()
plt.show()

# %%
from pandas.plotting import scatter_matrix
compare = ['budget', 'revenue', 'runtime', 'vote_average']
scatter_matrix(work_copy[compare])
# Out:
# array([[<Axes: xlabel='budget', ylabel='budget'>,
#         <Axes: xlabel='revenue', ylabel='budget'>,
#         <Axes: xlabel='runtime', ylabel='budget'>,
#         <Axes: xlabel='vote_average', ylabel='budget'>],
#        [<Axes: xlabel='budget', ylabel='revenue'>,
#         <Axes: xlabel='revenue', ylabel='revenue'>,
#         <Axes: xlabel='runtime', ylabel='revenue'>,
#         <Axes: xlabel='vote_average', ylabel='revenue'>],
#        [<Axes: xlabel='budget', ylabel='runtime'>,
#         <Axes: xlabel='revenue', ylabel='runtime'>,
#         <Axes: xlabel='runtime', ylabel='runtime'>,
#         <Axes: xlabel='vote_average', ylabel='runtime'>],
#        [<Axes: xlabel='budget', ylabel='vote_average'>,
#         <Axes: xlabel='revenue', ylabel='vote_average'>,
#         <Axes: xlabel='runtime', ylabel='vote_average'>,
#         <Axes: xlabel='vote_average', ylabel='vote_average'>]],
#       dtype=object)

# %%
c = work_copy[compare].corr()
print(c)
# Out:
#                 budget   revenue   runtime  vote_average
# budget        1.000000  0.768776  0.134733      0.073494
# revenue       0.768776  1.000000  0.103917      0.083868
# runtime       0.134733  0.103917  1.000000      0.158146
# vote_average  0.073494  0.083868  0.158146      1.000000

# %% [markdown]
# ## 2.
# On an initial view of the data there are two notable relations.
# The vote average and the budget seem to form a normal distribution.
# The budget and the revenue seem to share a positive correlation.
# Although not as strong as vote average and budget, there appears to be a normal distrubution between revenue and vote average as well.

# %% [markdown]
# ## 3.
# Features to predict:
# * Revenue from Budget
# * Vote Average from Budget
# * Revenue from Vote Average
#
# If I had to pick one it would be Revenue from Budget due to the strong correlation.

# %% [markdown]
# ## 4.

# %%
work_copy.dropna(axis='index', how='all', subset=['budget', 'vote_average', 'runtime', 'revenue'], inplace=True)

# %%
budget_gt_0 = work_copy.copy()
budget_gt_0 = work_copy['budget'] > 0
budget_gt_0.value_counts()
# Out:
# budget
# False    36573
# True      8890
# Name: count, dtype: int64

# %% [markdown]
# ## 5.

# %%
from sklearn.model_selection import train_test_split as tts
train_set, test_set = tts(work_copy, test_size=0.2, random_state=777)
working_train = train_set.copy()
working_test = test_set.copy()
